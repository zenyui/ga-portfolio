# %% [markdown]
# # Sample Data for Final Project

# %%
import pandas as pd

# %%
df = pd.read_csv('demo_data.csv', header=0)

# %%
df.describe()
# Out:
#          CustomerKey    VisitCount    VisitNumber    PriorVisits  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean   224326.619800       7.77551       5.480610       4.480610
# std    129950.331094      17.07087      12.317853      12.317853
# min         5.000000       1.00000       1.000000       0.000000
# 25%    112964.000000       1.00000       1.000000       0.000000
# 50%    220586.000000       2.00000       2.000000       1.000000
# 75%    336979.000000       7.00000       4.000000       3.000000
# max    453986.000000     246.00000     199.000000     198.000000
#
#           SaleLines   ReturnLines     NetAmount   UniqueItems  \
# count  99767.000000  99767.000000  99767.000000  99767.000000
# mean       3.657642      0.025349     28.401342      3.416761
# std        4.163389      0.169577     44.834917      3.735178
# min        0.000000      0.000000   -139.800000      1.000000
# 25%        1.000000      0.000000      8.300000      1.000000
# ...

# %%
df.sample(10)
# Out:
#        TicketDate TicketTime  CustomerKey  VisitCount  VisitNumber  \
# 31048   10/4/2015   19:10:10       409721           3            2
# 50949  10/12/2015   12:35:46        58482           2            1
# 84855  10/28/2015   13:29:14       100681           8            4
# 29744   10/3/2015   17:56:42       149540           2            1
# 7160    9/23/2015   16:50:14       274367           2            2
# 48498  10/11/2015   22:21:21       193032           1            1
# 31265   10/4/2015   17:36:30       450446           8            8
# 12530   9/25/2015   13:23:16       233303           1            1
# 78954  10/24/2015   15:54:19       134793           2            2
# 65602  10/19/2015   17:51:16       186376          23           16
#
#        PriorVisits  SaleLines  ReturnLines  NetAmount StationGroup  \
# 31048            1          8            0      47.21    Front End
# 50949            0          1            0      11.80        Other
# ...
